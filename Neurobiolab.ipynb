# %% [markdown]
# <a href="https://colab.research.google.com/github/nellyfadil/Neurobio/blob/main/Neurobiolab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from scipy.stats import skewtest
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats

# %%
#import data set
url = 'https://raw.githubusercontent.com/nellyfadil/Neurobio/main/Final%20Neurobio%20Data%20-%20Sheet1.csv'
alz_data = pd.read_csv(url)
alz_data
# Out:
#      donor_id        name sex apo_e4_allele dsm_iv_clinical_diagnosis  \
# 0   309335438  H14.09.001   M             N               No Dementia
# 1   309335439  H14.09.002   M             Y  Alzheimer's Disease Type
# 2   309335440  H14.09.003   M             N               No Dementia
# 3   309335441  H14.09.004   M             N               No Dementia
# 4   309335442  H14.09.005   F             Y       Multiple Etiologies
# ..        ...         ...  ..           ...                       ...
# 89  467056405  H15.09.106   M             N               No Dementia
# 90  467056406  H15.09.107   F             Y  Alzheimer's Disease Type
# 91  467056407  H15.09.108   F             N               No Dementia
# 92  467056408  H15.09.109   F             N  Alzheimer's Disease Type
# 93  467056409  H15.09.110   F             N  Alzheimer's Disease Type
#
#            nincds_arda_diagnosis  MAPT_intensity_HIP
# 0                    No Dementia               6.107
# ...

# %%
#Create Variables
Sex= alz_data.iloc[:,2]
Apoe_e4 = alz_data.iloc [:,3]
Diagnosis = alz_data.iloc[:,-2]
MAPT_intensity_HIP = alz_data.iloc[:,-1]

print(Apoe_e4)
# Out:
# 0     N
# 1     Y
# 2     N
# 3     N
# 4     Y
#      ..
# 89    N
# 90    Y
# 91    N
# 92    N
# 93    N
# Name: apo_e4_allele, Length: 94, dtype: object

# %%
#Create pie chart for grouping varbiables
#sex
colors = ['Royalblue', 'Red']
alz_data['sex'].value_counts().plot(kind = 'pie', colors = colors)
plt.ylabel('sex')
plt.show()

#diagnosis
plt.show()
colors = ['mistyrose', 'lightcoral','red', 'brown']
alz_data['nincds_arda_diagnosis'].value_counts().plot(kind='pie', colors=colors)
plt.ylabel('DSM IV Diagnosis')
# Out:
# Text(0, 0.5, 'DSM IV Diagnosis')

# %%
df = pd.DataFrame(alz_data)
plt.figure(figsize=(10,6))
boxplot = df.boxplot(column ='MAPT_intensity_HIP', by=['sex'], grid=False, patch_artist=True)

plt.title('Box Plot of MAPT Intensity by Sex')
plt.xlabel('Sex')
plt.ylabel('MAPT Log2 Intensity')

# Show the plot
plt.show()

# %%
df = pd.DataFrame(alz_data)
plt.figure(figsize=(10,6))
boxplot = df.boxplot(column ='MAPT_intensity_HIP', by=['Apoe_e4'], grid=False, patch_artist=True)

plt.title('Box Plot of MAPT Intensity by Apoe_e4')
plt.xlabel('Apoe Expression')
plt.ylabel('MAPT Log2 Intensity')

# Show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-40-ba3477df8298> in <cell line: 3>()
#       1 df = pd.DataFrame(alz_data)
#       2 plt.figure(figsize=(10,6))
# ----> 3 boxplot = df.boxplot(column ='MAPT_intensity_HIP', by=['Apoe_e4'], grid=False, patch_artist=True)
#       4
#       5 plt.title('Box Plot of MAPT Intensity by Apoe_e4')
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_core.py in boxplot_frame(self, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, backend, **kwargs)
#     514 ):
#     515     plot_backend = _get_plot_backend(backend)
# --> 516     return plot_backend.boxplot_frame(
#     517         self,
#     518         column=column,
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_matplotlib/boxplot.py in boxplot_frame(self, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, **kwds)
# ...
